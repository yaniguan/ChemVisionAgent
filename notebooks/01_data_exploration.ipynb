# %% [markdown]
# # 01 — Dataset Exploration
#
# Explore raw scientific images and inspect annotation quality.

# %%
from pathlib import Path
from chemvision.data.schema import DatasetConfig, ImageDomain

cfg = DatasetConfig(
    source_dir=Path('../data/raw'),
    output_dir=Path('../data/processed'),
)
print(cfg)

# %% [markdown]
# ## TODO
# - Load sample images per domain
# - Visualise annotation distribution
# - Check class balance across splits
