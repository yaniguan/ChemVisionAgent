# %% [markdown]
# # 02 — Model Inference Sandbox
#
# Load a model backend and run single-image inference interactively.

# %%
from chemvision.models.config import ModelConfig
from chemvision.models.qwen_vl import QwenVLWrapper

cfg = ModelConfig(
    model_name_or_path='Qwen/Qwen2-VL-7B-Instruct',
    device='cuda',
)
# model = QwenVLWrapper(cfg)
# model.load()
print('Model config ready:', cfg.model_name_or_path)

# %% [markdown]
# ## TODO
# - Implement QwenVLWrapper.load() and generate()
# - Test on sample spectrum and molecular diagram
# - Compare outputs across temperature settings
